# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/tinyml/blob/main/FA22_Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 8: Database & Visualization 2 – Grafana Dashboard

# %% [markdown]
# ## Introduction
#
# The topic of Lab8 is visualization using Grafana web dashboard. We will practice creating Grafana dashboard using the existing database first and then build up the entire system yourself to monitor sensor data using Grafana in real-time remotely. At the end of this lab, you will be able to create a real-time remote IIoT monitoring system from the sensors or IoT devices to a web-based dashboard.

# %% [markdown]
# ## Explore Grafana

# %% [markdown]
# ### Part 1: Log-in Grafana web server
#
# Let’s start with log in the Grafana server. The Grafana server domain and the port number information for this lab are as follows.
# * DNS: me597server1.ecn.purdue.edu
# * Port: 3000
#   * Please note that default port number of Grafana is 3000.
# * Grafana web page URL: http://me597server1.ecn.purdue.edu:3000/
#
# When you access the Grafana web page using a web browser on your laptop, you will see the log-in page as Figure 1. TA made an account for each of you. The username is the same as the MySQL account name, i.e., your username for Grafana is ‘firstnamelastname’ based on Brightspace, e.g., John Doe’s username for ME597 Grafana server if ‘johndoe’. Or you can use your Purdue email address as the log-in information. And TA will let you know the password of your account.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure1.png?raw=true)
#
# *Figure 1 Log-in page of Grafana server*
#
# After successfully logging on to the Grafana server, you will see the main page as Figure 2. When you put the mouse pointer on the profile icon, and then you will see the profile menu. If you want to change password or information of your account, try it.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure2.png?raw=true)
#
# *Figure 2 Grafana main page*

# %% [markdown]
# ### Part 2: Access to dashboard
#
# Before accessing the dashboard, let’s understand the system and the data first. The schematic of the example system for the dashboards is shown in Figure 4. This is important because you should create the same system by accessing the measurement data from sensors at the end of this lab. As we performed in Lab5,
# MTConnect adapter simulator is being used. The target sensors are 1) DHT11, 2) ADXL345, and 3) power meter. The example data are shown in Figure 3. These example data for approximately 3 minutes are repeating continuously and infinitely in the MTConnect adapter simulator. All simulated data is transmitted to MTConnect agent.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure3.png?raw=true)
#
# *Figure 3 Example data for the example dashboard*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure4.png?raw=true)
#
# *Figure 4 Schematic of example system*
#
# The information about the system is summarized as follows.
# * MTConnect agent: http://me597server1.ecn.purdue.edu:5000/
# * MySQL server DNS (same as Lab7): http://me597server1.ecn.purdue.edu
#   * Port: 3306
#   * Database: ME597Spring22
#   * Table: grafana_sample
#   * Table schema is the same as Lab7. But the only difference is the precision of the TIMESTAMP column. This is explained in the later section.
# * Sensor
#   * DHT11
#     * Temperature (Sample) in °C unit
#     * Humidity (Sample) in %RH unit
#   * DXL345
#     * X-axis acceleration (Sample) in m/s2 unit
#     * Y-axis acceleration (Sample) in m/s2 unit
#     * Z-axis acceleration (Sample) in m/s2 unit
#   * Power meter
#     * True power (Sample) of vacuum pump in Watt unit
#     * Power state (Event): ‘ON’ or ‘OFF’
#       * When the true power is larger than 0 W, the result is ‘ON’ which means the vacuum pump is running.
#
# If you request current information to MTConnect agent, you will see the result as Figure 5. By aggregating MTConnect agent data, the MySQL database (‘grafana_sample’ table) is updated continuously.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure5.png?raw=true)
#
# *Figure 5 Capture of current response from MTConnect agent*
#
# If you check the data in ‘grafana_sample’ table using SELECT statement as below on ‘MySQL Workbench’, you will see the result grid as Figure 6. If you compare the MTConnect agent data and MySQL database, you can confirm that all data in the MTConnect are aggregated into the database in real-time.
#
# ---
#
# **SQL - SELECT statement to see the table in descending order by timestamp**
#
# ```
# SELECT * FROM ME597Spring22.grafana_sample
# ORDER BY timestamp DESC;
# ```
#
# ---
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure6.png?raw=true)
#
# *Figure 6 Result grid of grafana_sample table*

# %% [markdown]
# #### TASK 1
#
# 1.	Capture your web browser after requesting ‘current’ information to the MTConnect agent as Figure 5 and attach it to the report.
# 2.	Capture your result grid as Figure 6 after querying the SELECT statement above to ‘grafana_sample’ table and attach it to the report.
# 3.	Answer to the questions below by comparing the MTConnect agent and the MySQL database table.
#
#   a.	What information in MTConnect agent is stored in the ‘timestamp’ column?
#
#   b.	What information in MTConnect agent is stored in the ‘sensor’ column?
#
#   c.	What information in MTConnect agent is stored in the ‘measurement’ column?
#
#   d.	What information in MTConnect agent is stored in the ‘value’ column?

# %% [markdown]
# Let’s go back to the Grafana webpage to see the example dashboard. To see the example dashboard (‘Lab8 dashboard example’) page, follow the steps () below.
#
# 1.	Click ‘Browse’ on the ‘Dashboards’ dropdown menu
#
#   a. You can see the dropdown menu when you put your mouse pointer on the ‘Dashboards’ icon on the ‘side menu bar’.
# 2.	Click ‘Lab8’ folder
# 3.	Click ‘Lab8 dashboard example’
#
#     ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image1.png?raw=true)
#
#
#
# You will see the example dashboard webpage as Figure 7. The brief description of each data visualization is as follows.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure7.jpg?raw=true)
#
# *Figure 7 Grafana Lab8 dashboard example*
#
#   a.	ADXL345 data (Sample) as Table
#
#   b.	Power data (Sample) as Time series
#
#   c.	Power state data (Event) as Discrete
#
#   d.	DHT11 temperature data (Sample) as Time series
#
#   e.	DHT11 humidity data (Sample) as Time series
#
#   f.	ADXL345 data (Sample) as Time series
#
# As you can see, the default time range of the dashboard is set as last 1 hour. To change the time range, click the time range icon on the right side of the top menu bar and then you will see the time range menu as Figure 8. If you click Last 5 minutes, the time range is changed from the last 5 minutes to now as Figure 9. Also, if you click the refresh icon, you will see the updated dashboard in real time.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure8.png?raw=true)
#
# *Figure 8 Time range menu of Grafana dashboard*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure9.png?raw=true)
#
# *Figure 9 Grafana Lab8 dashboard example after changing the time range to Last 5 minutes*
#
# If you want to see a graph or table in detail, click ‘View’ on the menu on the title of a graph as Figure 10. The example of DHT11 Temperature graph is shown in Figure 11. To go back to the dashboard page, click 'Go back' icon (a back arrow) or hit 'Esc' on your keyboard.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure10.jpg?raw=true)
#
# *Figure 10 View to see a graph in detail*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure11.jpg?raw=true)
#
# *Figure 11 Detail view of DHT11 Temperature graph.*

# %% [markdown]
# ### Part 3: Create folder and dashboard
#
# Now, let’s create sample dashboards to practice Grafana and SQL query. To create your dashboard page, follow the steps below. Please note that the data source (MySQL database) setup was done by TA.
#
# 1.	Go back to the ‘Dashboards’ page by clicking on ‘Browse’.
# 2.	Create your folder by clicking on ‘New Folder’
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image2.jpg?raw=true)
#
#
#
# 3.	Make the folder name as your name in the form of ‘Firstname Lastname’, e.g., John Doe, and then click ‘Create’
#
#   a. You will work in this folder for the following activities.
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image3.jpg?raw=true)
#
#
#
# 4.	Click ‘Create Dashboard’
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image4.jpg?raw=true)
#
# You will see the ‘New dashboard’ as Figure 12. Now, you are ready to create panels. Save the created dashboard as ‘Practice’ as Figure 13 by clicking the ‘Save dashboard’ icon on the right side of the top menu bar. Please be make sure that the Folder should be the folder you created.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure12.jpg?raw=true)
#
# *Figure 12 Grafana new dashboard*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure13.jpg?raw=true)
#
# *Figure 13 Save dashboard*

# %% [markdown]
# ### Part 4: Practice i) Time series
#
# Let’s add panels to your dashboard. We will practice three different types of panels (see the dashboard ‘Lab8/Lab8 sample’): 1) Time series as Figure 7d, 2) Table as Figure 7a, and 3) Discrete as Figure 7c. To create Time series panel for DHT11 temperature data visualization, please follow the steps below.
#
# 1.	Click ‘add panel’ icon on the top menu bar.
# 2.	Click ‘Add a new panel’ and then you will see the panel editing page as Figure 14. Each section of the page is described below.
#
#   a.	Preview section: You can see the preview of the panel you are editing.
#
#   b.	Query section: You can customize query to request data to the database
#
#   c.	Property section: You can manipulate the appearances of the panel
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure14.png?raw=true)
#
# *Figure 14 Panel editing page*
#
# 3.	Click ‘Toggle text edit mode’ icon (pencil) in the Query section to switch to the SQL query statement
#
#   a.	Please note that in this lab, you do not need to change ‘Data source’ because the ‘ME597Spring22’ MySQL database is set by the default data source of this Grafana server. However, when you need to use a different data source, ask it the administrator of the Grafana server.
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image5.jpg?raw=true)
#
# 4.	Write down the SELECT statement below to get ‘timestamp’ and ‘value’ to visualize temperature data according to time on the Query section.
#
# ---
#
# **SQL - SELECT statement for Part 4**
#
# ```
# SELECT
#   timestamp AS "time",
#   0+value as "Temperature"
# FROM grafana_sample
# WHERE
#   $__timeFilter(timestamp) AND
#   measurement = "temp" AND
#   value != "UNAVAILABLE"
# ORDER BY timestamp
#
# ```
#
# ---
#
# ---
#
# **Tip - SELECT statement in Grafana**
#
# 1.	The reason why put ‘0+’ in front of ‘value’ column in the SELECT statement is to make the data in a numeric data type. We set up the ‘value’ column in the MySQL as ‘TINYTEXT’ that means basically return data is string data type.
# 2.	In addition, in the WHERE clause, ‘value != “UNAVAILABLE”’ makes your SELECT statement exclude “UNAVAILABE” data in the ‘value’ column.
# 3.	‘\$\__’ is indicating the macro function in Grafana to correlate the time range of Grafana interface with the database. ‘$__timeFilter(timestamp)’ means timestamps between the given time range. If you click ‘Show Help’ in the Query section, you will see the details of descriptions about the macro as below.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image6.png?raw=true)
#
# ---
#
# 5.	Make ‘Title’ as ‘DHT11 Temperature’ on the Property section
# 6.	Make ‘Label’ as ‘Temperature’ on the Property section
# 7.	Select ‘Unit’ as ‘Celsius (°C)’ on the Property section
#
#   a.	You will find ‘Unit’ and ‘Label’ properties if scroll down on the Property section. 8. Click ‘Apply’ on the right side on the top menu
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image7.png?raw=true)
#
# You will see the created panel for DHT11 temperature data as Figure 15. *Please note that if you want to add more data in the same graph panel as Figure 7f, click ‘+Query’ on the bottom of the Query section.*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure15.jpg?raw=true)
#
# *Figure 15 Panel added 1: DHT11 temperature*

# %% [markdown]
# ### Part 5: Practice ii) Table
#
# Let’s add Table panel for ADXL345 sensor data in table format as Figure 7a. Follow the steps below.
#
# 1.	Click ‘add panel’ icon on the top menu bar and then click ‘Add a new panel’ as you did in the previous part
# 2.	In the panel editing page, click ‘Click to change visualization’
# 3.	Click ‘Table’
# 4.	Click ‘Toggle text edit mode’ icon in the Query section to switch to the SQL query statement
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image8.png?raw=true)
#
# 5.	Write down the SELECT statement below to get data to visualize the ADXL345 sensor data in the table format on the Query section.
#
#   a. In this case, because table can show both string and numeric data, you do not need to put ‘+0’ in front of the ‘value’ column in SELECT statement.
#
# ---
#
# **SQL - SELECT statement for Part 5**
#
# ```
# SELECT
#   timestamp AS "time",
#   sensor,
#   measurement,
#   value
# FROM grafana_sample
# WHERE
#   $__timeFilter(timestamp) AND
#   sensor = "ADXL345"
# ORDER BY timestamp
#
# ```
#
# ---
#
# 6.	Make ‘Title’ as ‘ADXL345 sensor data’
# 7.	Click ‘Apply’
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image9.jpg?raw=true)
#
# You will see the created Table panel for ADXL345 sensor data as Figure 16. Please note that the Table panel is good to show EVENT data such as alarm, condition, state and so on.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure16.jpg?raw=true)
#
# *Figure 16 Panel added 2: ADXL345 sensor data table*

# %% [markdown]
# ### Part 6: Practice iii) Table
#
# Let’s add Discrete panel as Figure 7c. The Discrete panel allows us to see the discrete Event data in a direct and straightforward way. To create Discrete panel for power state data, please follow the steps below.
#
# 1.	Click ‘add panel’ icon on the top menu bar and then click ‘Add a new panel’ as you did in the previous part
# 2.	In the panel editing page, click ‘Click to change visualization’
# 3.	Click ‘Discrete’
# 4.	Click ‘Toggle text edit mode’ icon in the Query section to switch to the SQL query statement
#
#   ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image10.png?raw=true)
#
# 5.	Write down the SELECT statement below to get discrete Event data to visualize the power state of vacuum pump on the Query section.
#
# ---
#
# **SQL - SELECT statement for Part 6**
#
# ```
# SELECT
#   timestamp AS "time",
#   value AS "Power state"
# FROM grafana_sample
# WHERE
#   $__timeFilter(timestamp) AND
#   measurement = "powerstate"
# ORDER BY timestamp
#
# ```
#
# ---
#
# 6.	Make ‘Title’ as ‘Power state dashboard’
# 7.	Click ‘Apply’
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Image11.jpg?raw=true)
#
# You will see the created Discrete panel for power state Event data as Figure 17. Also, you can adjust each panel size by using mouse. To change the size of the panel, put your mouse pointer on the corner of the panel. To move the panel, put your mouse pointer on the title, and then drag to another placement as Figure 18. Please note that after every update of your dashboard, please save it!
#
#
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure17.jpg?raw=true)
#
# *Figure 17 Panel added 3: Power state discrete Event data*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure18.jpg?raw=true)
#
# *Figure 18 Added panels after adjusting each panel size and the placement.*

# %% [markdown]
# #### TASK 2
#
# After performing the above parts, capture your created dashboard (‘Practice’) as Figure 18 and then attach it to the report. Do not remove the dashboard even after finishing this TASK. Please make sure that your dashboard should be in your folder.

# %% [markdown]
# ## Build Up The Entire Monitoring System
#
# Finally, in this section, you need to build up the entire system as Figure 19. Perform the last task below. MTConnect collector Python script (the answer of deliverable 2 of Prelab8) using XML parsing is given on Brightspace. But you need to modify some front parts indicated with asteriks below.
#
# ---
#
# **Python - Python3 (mtconnect_collector.py)**
#
# ```
# ## Credential
# * HOST = 'MySQL HOST DNS' # MySQL server host DNS
# PORT = 3306 # MySQL server port number
# * USER = 'your account' # MySQL account name
# * PASSWORD = 'your password' # Password of the account
# * DB = 'Database information' # DB name
# * TABLE = 'your table name' # table name
# ## Credential
#
# ## MTConnect info.
# * agent = "agent host"
# * agent_port = "agent port number"
# url_current = "http://"+agent+":"+agent_port+"/current"
# MTCONNECT_STR = ET.fromstring(requests.get(url_current).content).tag.split("}")[0]+"}"
# print("MTConnect string header is {}.".format(MTCONNECT_STR))
# ## MTConnect info.
#
# ```

# %% [markdown]
# #### TASK 3
#
# 1. Build up the entire monitoring system as Figure 19. The requirements are below.
#
#   a.	You need to measure all three-sensor data (DHT11, ADXL345, and power meter): This is the same as you did in Lab6.
#
#     * DHT11: temperature (Sample)
#     * DHT11: humidity (Sample)
#     * ADXL345: X-axis acceleration (Sample)
#     * ADXL345: Y-axis acceleration (Sample)
#     * ADXL345: Z-axis acceleration (Sample)
#     * Power meter: True power consumption (Sample)
#     * Power meter: Power state (Event) – ‘ON’ or ‘OFF’ by a logic based on the measured true power consumption
#
#   b.	The sample period of each sensor is 2, 1, and 1 second, respectively.
#
#   c.	Follow MTConnect standard as much as you can.
#
#   d.	Use the MySQL database table you created in Lab7 (‘yourname_lab7’).
#     * However please update your ‘timestamp’ column property to have 6 decimal precision of ‘TIMESTAMP’ data type as Figure 20.
#
#   e.	**Hint1: You can make ‘device.xml’ based on
# ‘http://me597server1.ecn.purdue.edu:5000/probe’**
#
#   f.	**Hint2: Refer to the activities of Lab6 (MTConnect adapter) PART 3.**
#
# 2.	Create a Grafana dashboard as the title of ‘TASK3’ in your name folder
# 3.	Make panels in the created dashboard as Figure 7 (‘LAB8/LAB8 dashboard example’)
# 4.	Capture the created dashboard as Figure 7 and then attach it to the report.
# 5.	Upload both ‘device.xml’ and ‘agent.cfg’ files on Brightspace.
#
#   * Hint1: You can make ‘device.xml’ based on ‘http://me597server1.ecn.purdue.edu:5000/probe’
#   * Hint2: Recall to the activities of Lab6 (MTConnect adapter) PART 3.
#   * Hint3: It does not matter on which computer (Raspberry Pi or laptop) you run the
# ‘mtconnect_collector.py’. But please make sure the MySQL credentials and the MTConnect agent information.

# %% [markdown]
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure19.png?raw=true)
#
# *Figure 19 Schematic of the entire monitoring system for Lab8*
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L8_Figure20.png?raw=true)
#
# *Figure 20 TIMESTAMP datatype update (TIMESTAMP(6))*

# %% [markdown]
# ## Deliverable
#
# 1.	Summarize Lab 8 what you performed and learned.
#   * Use any photos, figures, tables, and equations if needed.
# 2.	Perform all Tasks and submit your Lab8 report on Brightspace before Lab 9.
# 3.	It is possible to build up the IIoT monitoring system without MTConnect. Discuss the cons and pros of using MTConnect in the system.
# 4.	Can you build up the system without MTConnect, and how? Justify your strategies.
#
#   a. You don’t need to answer this question in detail. Answer this question in terms of the system configuration and the software you should use without MTConnect.
